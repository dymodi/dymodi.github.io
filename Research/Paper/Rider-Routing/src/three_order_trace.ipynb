# %%
# 画骑手的3单轨迹
# 2018/07/27

import matplotlib.pyplot as plt
import gmplot
import pandas as pd
import os
import random
import collections

# Path Assign
data_path = '/Users/eleme-yi/Downloads'
figure_path = '/Users/eleme-yi/Documents/GitHubPages/dymodi.github.io/Research/Paper/Rider-Routing/figures/'

# %%
# Read data
# file_name = 'three_order_trace_test_072718.xlsx'
file_name = 'four_order_trace_test_073118.xlsx'
df_three_order_trace_all = pd.read_excel(os.path.join(data_path, file_name))
print(df_three_order_trace_all.head(10))
# Out:
#     rider_id  rn          tracking_id  shipping_state           ocurred_time  \
# 0   10599343   1  3000041089314106454              20  2018-07-31 00:00:22.0
# 1   10599343   1  3000041089655418624              20  2018-07-31 00:06:21.0
# 2   10599343   1  3000041089314106454              80  2018-07-31 00:17:24.0
# 3   10599343   1  3000041089314106454              30  2018-07-31 00:20:32.0
# 4   10599343   1  3000041089655418624              80  2018-07-31 00:22:50.0
# 5   10599343   1  3000041089655418624              30  2018-07-31 00:23:03.0
# 6   10599343   1  3000041089655418624              40  2018-07-31 00:30:39.0
# 7   10599343   1  3000041089314106454              40  2018-07-31 00:41:47.0
# 8  120256746   4  3000041089645982727              20  2018-07-31 00:01:56.0
# 9  120256746   4  3000041088554153883              20  2018-07-31 00:02:56.0
#
#     latitude   longitude  shop_latitude  shop_longitude
# 0  30.948944  118.761751      30.948448      118.759429
# 1  30.949503  118.759430      30.949251      118.762556
# 2  30.949429  118.759366      30.948448      118.759429
# 3  30.949090  118.759299      30.948448      118.759429
# 4  30.949360  118.762423      30.949251      118.762556
# 5  30.949400  118.762592      30.949251      118.762556
# 6  30.942355  118.761633      30.949251      118.762556
# 7  30.949425  118.782178      30.948448      118.759429
# 8  25.430583  105.214316      25.430823      105.204011
# 9  25.430629  105.214327      25.432061      105.189600

# %%
# Draw by rn
fig_limit = 20
waypoint_size = 200
rn_list = df_three_order_trace_all['rn'].drop_duplicates().tolist()

fig_num = 0
for rn in rn_list:
    fig_num = fig_num + 1
    # Break if reach limit
    if fig_num > fig_limit:
        break
    # Extract data
    index_rn = df_three_order_trace_all['rn'] == rn
    df_trace = df_three_order_trace_all[index_rn]
    
    lat_cen = df_trace['latitude'].iloc[0]
    lon_cen = df_trace['longitude'].iloc[0]

    gmap = gmplot.GoogleMapPlotter(lat_cen, lon_cen, 16)
    
    index_20 = df_trace['shipping_state'] == 20
    index_80 = df_trace['shipping_state'] == 80
    index_30 = df_trace['shipping_state'] == 30
    index_40 = df_trace['shipping_state'] == 40
    
    df_20 = df_trace[index_20]
    df_80 = df_trace[index_80]
    df_30 = df_trace[index_30]
    df_40 = df_trace[index_40]

    lat_list = df_trace['latitude'].tolist()
    lon_list = df_trace['longitude'].tolist()
    gmap.plot(lat_list, lon_list,'yellowgreen', size = waypoint_size, edge_width=7)
    
    # Shop location
    lat_shop_list = df_20['shop_latitude'].tolist()
    lon_shop_list = df_20['shop_longitude'].tolist()
    gmap.scatter(lat_shop_list, lon_shop_list, 'black', size = waypoint_size, marker=True)
    
    # lat_20_list = df_20['latitude'].tolist()
    # lon_20_list = df_20['longitude'].tolist()
    # gmap.scatter(lat_20_list, lon_20_list, 'darkgreen', size = waypoint_size, marker=True)
    
    # lat_80_list = df_80['latitude'].tolist()
    # lon_80_list = df_80['longitude'].tolist()
    # gmap.scatter(lat_80_list, lon_80_list, 'gold', size = waypoint_size, marker=True)
    
    # lat_30_list = df_30['latitude'].tolist()
    # lon_30_list = df_30['longitude'].tolist()
    # gmap.scatter(lat_30_list, lon_30_list, 'salmon', size = waypoint_size, marker=True)
    
    # Delivery
    lat_40_list = df_40['latitude'].tolist()
    lon_40_list = df_40['longitude'].tolist()
    gmap.scatter(lat_40_list, lon_40_list, 'cyan', size = waypoint_size, marker=True)
    
    file_name = '_'.join(['three_order_trace', str(rn)])
    file_name = '.'.join([file_name,'html'])
    figure_name = os.path.join(figure_path, file_name)
    
    gmap.draw(figure_name)

# %%
## 这里我们看一下同样三个店，不同骑手的选择是否一样
# Read data
# file_name = 'three_order_trace_test_072718.xlsx'
file_name = 'three_order_two_rider_same_shops.xlsx'
df_three_order_two_rider_trace_all = pd.read_excel(os.path.join(data_path, file_name))
print(df_three_order_two_rider_trace_all.head(10))
# Out:
#    rider_id_1    rn_1        tracking_id_1  shipping_state_1  \
# 0   100001849  180591  2100003350969587772                20
# 1   100001849  180591  2100003350896089148                20
# 2   100001849  180591  2100003350969587772                80
# 3   100001849  180591  2100003350896089148                80
# 4   100001849  180591  2100003350329203342                80
# 5   100001849  180591  2100003350969587772                30
# 6   100001849  180591  2100003350896089148                30
# 7   100001849  180591  2100003350969587772                40
# 8   100001849  180591  2100003350896089148                40
# 9   100001849  180591  2100003350329203342                30
#
#           ocurred_time_1  latitude_1  longitude_1  inner_rn_1  shop_id_1  \
# 0  2018-11-18 12:50:34.0   37.724243   112.585719           2  166985482
# 1  2018-11-18 12:52:31.0   37.724388   112.580366           3  166985482
# 2  2018-11-18 12:55:12.0   37.727848   112.575864           4  166985482
# 3  2018-11-18 12:55:15.0   37.727848   112.575864           5  166985482
# 4  2018-11-18 12:56:05.0   37.736285   112.573945           6    1034471
# 5  2018-11-18 12:58:12.0   37.736231   112.573915           7  166985482
# 6  2018-11-18 13:01:25.0   37.736269   112.573954           8  166985482
# 7  2018-11-18 13:06:56.0   37.738962   112.573069           9  166985482
# 8  2018-11-18 13:15:22.0   37.742761   112.577798          10  166985482
# 9  2018-11-18 13:21:22.0   37.737788   112.572347          11    1034471
#
#    shop_id_2  shop_latitude  shop_longitude  rider_id_2    rn_2  \
# 0  143279133      37.736136      112.573826   106895866  428056
# 1  166985482      37.736136      112.573826   106895866  428056
# 2  143279133      37.736136      112.573826   106895866  428056
# 3  155845424      37.736136      112.573826   106895866  428056
# 4  155845424      37.737871      112.572332   106895866  428056
# 5  166985482      37.736136      112.573826   106895866  428056
# 6  143279133      37.736136      112.573826   106895866  428056
# 7  166985482      37.736136      112.573826   106895866  428056
# 8  143279133      37.736136      112.573826   106895866  428056
# 9  166985482      37.737871      112.572332   106895866  428056
#
#          tracking_id_2  shipping_state_2         ocurred_time_2  latitude_2  \
# 0  1200042466365348245                20  2018-11-18 20:00:27.0   37.731166
# 1  1200042466001393724                20  2018-11-18 20:00:28.0   37.731166
# 2  1200042466365348245                80  2018-11-18 20:01:10.0   37.732918
# 3  1200042463993075821                80  2018-11-18 20:02:46.0   37.737811
# 4  1200042463993075821                30  2018-11-18 20:05:36.0   37.737826
# 5  1200042466001393724                80  2018-11-18 20:07:27.0   37.735305
# 6  1200042466365348245                30  2018-11-18 20:13:32.0   37.733919
# 7  1200042466001393724                30  2018-11-18 20:15:45.0   37.736170
# 8  1200042466365348245                40  2018-11-18 20:20:56.0   37.742345
# 9  1200042466001393724                40  2018-11-18 20:23:51.0   37.745708
#
#    longitude_2  inner_rn_2
# 0   112.568937           2
# 1   112.568937           3
# 2   112.568834           4
# 3   112.567928           5
# 4   112.568157           6
# 5   112.572572           7
# 6   112.572735           8
# 7   112.573971           9
# 8   112.575105          10
# 9   112.576349          11

# %%
# Get list zip
rn_1_list = df_three_order_two_rider_trace_all['rn_1'].tolist()
rn_2_list = df_three_order_two_rider_trace_all['rn_2'].tolist()

fig_limit = 20
waypoint_size = 200

fig_num = 0

for rn_tuple in collections.OrderedDict.fromkeys(zip(rn_1_list, rn_2_list)):
    print(rn_tuple[0],rn_tuple[1])
    fig_num = fig_num + 1
    # Break if reach limit
    if fig_num > fig_limit:
        break
    # Extract data
    index_rn_1 = df_three_order_two_rider_trace_all['rn_1'] == rn_tuple[0]
    df_trace_raw = df_three_order_two_rider_trace_all[index_rn_1]
    index_rn_2 = df_three_order_two_rider_trace_all['rn_2'] == rn_tuple[1]
    df_trace = df_three_order_two_rider_trace_all[index_rn_2]
    
    lat_cen = df_trace['latitude_1'].iloc[0]
    lon_cen = df_trace['longitude_1'].iloc[0]

    gmap = gmplot.GoogleMapPlotter(lat_cen, lon_cen, 16)
    
    gmap.apikey = 'AIzaSyDfydMqxIwwx_6n0uvmTDAI_qYT7dy-61E'
    
    # Plot shop lat/lon
    lat_shop_list = df_trace['shop_latitude'].tolist()
    lon_shop_list = df_trace['shop_longitude'].tolist()
    gmap.scatter(lat_shop_list, lon_shop_list, 'black', size = waypoint_size, marker=True)
    
    # Plot rider_1 trace
    lat_list_1 = df_trace['latitude_1'].tolist()
    lon_list_1 = df_trace['longitude_1'].tolist()
    gmap.plot(lat_list_1, lon_list_1,'yellowgreen', size = waypoint_size, edge_width=7)
    gmap.scatter([lat_list_1[0]], [lon_list_1[0]],'yellowgreen', size = waypoint_size, marker=True)
    
    # Plot rider_2 trace
    lat_list_2 = df_trace['latitude_2'].tolist()
    lon_list_2 = df_trace['longitude_2'].tolist()
    gmap.plot(lat_list_2, lon_list_2,'cyan', size = waypoint_size, edge_width=7)
    gmap.scatter([lat_list_2[0]], [lon_list_2[0]],'cyan', size = waypoint_size, marker=True)
    
    file_name = '_'.join(['three_order_two_rider_trace', str(rn_tuple[0]),str(rn_tuple[1])])
    file_name = '.'.join([file_name,'html'])
    figure_name = os.path.join(figure_path, file_name)
    
    gmap.draw(figure_name)
# Out:
# 180591 428056
# saved
# 180591 383245
# saved
# 316363 32913
# saved
# 262028 182578
# saved
# 262028 403611
# saved
# 262028 393699
# saved
# 14027 212916
# saved
# 257350 131894
# saved
# 287802 276887
# saved
# 287802 37516
# saved
# 40222 209953
# saved
# 40222 367653
# saved
# 401173 462508
# saved
# 2753 8350
# saved
# 18352 2819
# saved
# 18352 88086
# saved
# 35346 48185
# saved
# 35346 448311
# saved
# 433784 201088
# saved
# 184422 48675
# saved
# 184422 24092
